# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('./occupations.csv')
df.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
df[df['gender']=='F']['occupation'].value_counts()b
# Out:
# student          60
# other            36
# administrator    36
# librarian        29
# educator         26
# writer           19
# artist           13
# healthcare       11
# marketing        10
# homemaker         6
# programmer        6
# none              4
# executive         3
# scientist         3
# salesman          3
# engineer          2
# lawyer            2
# entertainment     2
# retired           1
# technician        1
# Name: occupation, dtype: int64

# %%
df[df['gender']=='M']['occupation'].value_counts()
# Out:
# student          136
# other             69
# educator          69
# engineer          65
# programmer        60
# administrator     43
# executive         29
# scientist         28
# technician        26
# writer            26
# librarian         22
# entertainment     16
# marketing         16
# artist            15
# retired           13
# lawyer            10
# salesman           9
# doctor             7
# none               5
# healthcare         5
# homemaker          1
# Name: occupation, dtype: int64

# %%
df2=df[['Life expectancy at birth- years','Internet users percentage of population 2014','Forest area percentage of total land area 2012', 'Carbon dioxide emissionsAverage annual growth']]

df2.head()
# Out:
#    Life expectancy at birth- years  \
# 0                             81.6
# 1                             82.4
# 2                             83.0
# 3                             80.2
# 4                             81.6
#
#    Internet users percentage of population 2014  \
# 0                                         96.30
# 1                                         84.56
# 2                                         87.00
# 3                                         95.99
# 4                                         93.17
#
#    Forest area percentage of total land area 2012  \
# 0                                       27.973433
# 1                                       19.193731
# 2                                       31.612511
# 3                                       12.915390
# 4                                       10.824437
#
#    Carbon dioxide emissionsAverage annual growth
# 0                                       0.778925
# ...

# %%
sns.pairplot(df2)

# %%
a=[44,42,43,28,46,33,42,37,29]

a.sort()
a
# Out:
# [28, 29, 33, 37, 42, 42, 43, 44, 46]

# %%
b=[33,45,98,38,21,49,51,58,82,75]

b.sort()

import numpy as np

# %%
np.median(b)
# Out:
# 50.0

# %%
df3=pd.read_csv('young_survey.csv')

df3.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...  Spending on looks  \
# 0      1.0  5.0   5.0                1.0  ...                3.0
# 1      2.0  3.0   5.0                4.0  ...                2.0
# 2      5.0  3.0   5.0                3.0  ...                3.0
# 3      1.0  2.0   2.0                1.0  ...                4.0
# 4      3.0  5.0   3.0                1.0  ...                3.0
#
#    Spending on gadgets  Spending on healthy eating   Age  Height  Weight  \
# ...
